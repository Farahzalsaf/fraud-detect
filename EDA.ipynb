# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
client=pd.read_csv("./train/client_train.csv")
client
# Out:
#         disrict           client_id  client_catg  region creation_date  target
# 0            60      train_Client_0           11     101    31/12/1994     0.0
# 1            69      train_Client_1           11     107    29/05/2002     0.0
# 2            62     train_Client_10           11     301    13/03/1986     0.0
# 3            69    train_Client_100           11     105    11/07/1996     0.0
# 4            62   train_Client_1000           11     303    14/10/2014     0.0
# ...         ...                 ...          ...     ...           ...     ...
# 135488       62  train_Client_99995           11     304    26/07/2004     0.0
# 135489       63  train_Client_99996           11     311    25/10/2012     0.0
# 135490       63  train_Client_99997           11     311    22/11/2011     0.0
# 135491       60  train_Client_99998           11     101    22/12/1993     0.0
# 135492       60  train_Client_99999           11     101    18/02/1986     0.0
#
# [135493 rows x 6 columns]

# %%
invoice=pd.read_csv("./train/invoice_train.csv")
invoice
# Out:
# C:\Users\rohan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 0                    0           203                 8                    1
# 1                    0           203                 6                    1
# 2                    0           203                 8                    1
# 3                    0           207                 8                    1
# 4                    0           207                 9                    1
# ...                ...           ...               ...                  ...
# 4476744              0           202                 9                    1
# 4476745              0           202                 6                    1
# 4476746              0           203                 6                    1
# 4476747              0           203                 6                    1
# 4476748              0           203                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index  months_number  \
# 0                           0      14302      14384              4
# 1                           0      12294      13678              4
# 2                           0      14624      14747              4
# 3                           0      14747      14849              4
# 4                           0      15066      15638             12
# ...                       ...        ...        ...            ...
# 4476744                     0       3197       3732              8
# 4476745                     0       3732       3938              4
# 4476746                     0      13884      14143              4
# 4476747                     0      13281      13884              4
# 4476748                     0      12765      13281              4
#
#         counter_type
# 0               ELEC
# 1               ELEC
# 2               ELEC
# 3               ELEC
# 4               ELEC
# ...              ...
# 4476744         ELEC
# 4476745         ELEC
# 4476746         ELEC
# 4476747         ELEC
# 4476748         ELEC
#
# [4476749 rows x 16 columns]

# %%
sns.countplot(client.target)
# Out:
# C:\Users\rohan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
client.target.value_counts()
# Out:
# 0.0    127927
# 1.0      7566
# Name: target, dtype: int64

# %%
7566/(7566+127927)*100
# Out:
# 5.584052312665599

# %%
client
# Out:
#         disrict           client_id  client_catg  region creation_date  target
# 0            60      train_Client_0           11     101    31/12/1994     0.0
# 1            69      train_Client_1           11     107    29/05/2002     0.0
# 2            62     train_Client_10           11     301    13/03/1986     0.0
# 3            69    train_Client_100           11     105    11/07/1996     0.0
# 4            62   train_Client_1000           11     303    14/10/2014     0.0
# ...         ...                 ...          ...     ...           ...     ...
# 135488       62  train_Client_99995           11     304    26/07/2004     0.0
# 135489       63  train_Client_99996           11     311    25/10/2012     0.0
# 135490       63  train_Client_99997           11     311    22/11/2011     0.0
# 135491       60  train_Client_99998           11     101    22/12/1993     0.0
# 135492       60  train_Client_99999           11     101    18/02/1986     0.0
#
# [135493 rows x 6 columns]

# %%
client.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135493 entries, 0 to 135492
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   disrict        135493 non-null  int64
#  1   client_id      135493 non-null  object
#  2   client_catg    135493 non-null  int64
#  3   region         135493 non-null  int64
#  4   creation_date  135493 non-null  object
#  5   target         135493 non-null  float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 6.2+ MB

# %%
client['Day']=client['creation_date'].apply(lambda x:int(x.split('/')[0]))
client['Month']=client['creation_date'].apply(lambda x:int(x.split('/')[1]))
client['Year']=client['creation_date'].apply(lambda x:int(x.split('/')[2]))
client
# Out:
#         disrict           client_id  client_catg  region creation_date  \
# 0            60      train_Client_0           11     101    31/12/1994
# 1            69      train_Client_1           11     107    29/05/2002
# 2            62     train_Client_10           11     301    13/03/1986
# 3            69    train_Client_100           11     105    11/07/1996
# 4            62   train_Client_1000           11     303    14/10/2014
# ...         ...                 ...          ...     ...           ...
# 135488       62  train_Client_99995           11     304    26/07/2004
# 135489       63  train_Client_99996           11     311    25/10/2012
# 135490       63  train_Client_99997           11     311    22/11/2011
# 135491       60  train_Client_99998           11     101    22/12/1993
# 135492       60  train_Client_99999           11     101    18/02/1986
#
#         target  Day  Month  Year
# 0          0.0   31     12  1994
# 1          0.0   29      5  2002
# 2          0.0   13      3  1986
# 3          0.0   11      7  1996
# 4          0.0   14     10  2014
# ...        ...  ...    ...   ...
# 135488     0.0   26      7  2004
# 135489     0.0   25     10  2012
# 135490     0.0   22     11  2011
# 135491     0.0   22     12  1993
# 135492     0.0   18      2  1986
#
# [135493 rows x 9 columns]

# %%
client.client_catg.value_counts()
# Out:
# 11    131494
# 12      2321
# 51      1678
# Name: client_catg, dtype: int64

# %%
client[client['client_catg']==12]['target'].value_counts()
# Out:
# 0.0    2229
# 1.0      92
# Name: target, dtype: int64

# %%
client[client['client_catg']==51]['target'].value_counts()
# Out:
# 0.0    1395
# 1.0     283
# Name: target, dtype: int64

# %%
92/(92+2229)*100
# Out:
# 3.963808703145196

# %%
283/(283+1395)*100
# Out:
# 16.865315852205008

# %%
client[client.target==1]['region'].value_counts()/client['region'].value_counts() *100
# Out:
# 101     3.591946
# 103    10.296743
# 104     5.596580
# 105     5.592705
# 106     7.507082
# 107     6.581316
# 199          NaN
# 206     1.886792
# 301     3.300503
# 302     6.170262
# 303     5.449682
# 304     6.687565
# 305     5.780560
# 306     4.864328
# 307     6.220379
# 308     7.253270
# 309     4.306351
# 310     5.091734
# 311     8.044495
# 312     4.978306
# 313     7.080925
# 371     7.167070
# 372    10.093168
# 379     6.689537
# 399     0.571429
# Name: region, dtype: float64

# %%
sns.heatmap(client.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---------------------------

# %%
invoice
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 0                    0           203                 8                    1
# 1                    0           203                 6                    1
# 2                    0           203                 8                    1
# 3                    0           207                 8                    1
# 4                    0           207                 9                    1
# ...                ...           ...               ...                  ...
# 4476744              0           202                 9                    1
# 4476745              0           202                 6                    1
# 4476746              0           203                 6                    1
# 4476747              0           203                 6                    1
# 4476748              0           203                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index  months_number  \
# 0                           0      14302      14384              4
# 1                           0      12294      13678              4
# 2                           0      14624      14747              4
# 3                           0      14747      14849              4
# 4                           0      15066      15638             12
# ...                       ...        ...        ...            ...
# 4476744                     0       3197       3732              8
# 4476745                     0       3732       3938              4
# 4476746                     0      13884      14143              4
# 4476747                     0      13281      13884              4
# 4476748                     0      12765      13281              4
#
#         counter_type
# 0               ELEC
# 1               ELEC
# 2               ELEC
# 3               ELEC
# 4               ELEC
# ...              ...
# 4476744         ELEC
# 4476745         ELEC
# 4476746         ELEC
# 4476747         ELEC
# 4476748         ELEC
#
# [4476749 rows x 16 columns]

# %% [markdown]
# Old index and new index seems to show the change in consumption. Hence we should consider their difference as  a new feature:

# %%
invoice['diff_index']=invoice['new_index']-invoice['old_index']
invoice
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 0                    0           203                 8                    1
# 1                    0           203                 6                    1
# 2                    0           203                 8                    1
# 3                    0           207                 8                    1
# 4                    0           207                 9                    1
# ...                ...           ...               ...                  ...
# 4476744              0           202                 9                    1
# 4476745              0           202                 6                    1
# 4476746              0           203                 6                    1
# 4476747              0           203                 6                    1
# 4476748              0           203                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index  months_number  \
# 0                           0      14302      14384              4
# 1                           0      12294      13678              4
# 2                           0      14624      14747              4
# 3                           0      14747      14849              4
# 4                           0      15066      15638             12
# ...                       ...        ...        ...            ...
# 4476744                     0       3197       3732              8
# 4476745                     0       3732       3938              4
# 4476746                     0      13884      14143              4
# 4476747                     0      13281      13884              4
# 4476748                     0      12765      13281              4
#
#         counter_type  diff_index
# 0               ELEC          82
# 1               ELEC        1384
# 2               ELEC         123
# 3               ELEC         102
# 4               ELEC         572
# ...              ...         ...
# 4476744         ELEC         535
# 4476745         ELEC         206
# 4476746         ELEC         259
# 4476747         ELEC         603
# 4476748         ELEC         516
#
# [4476749 rows x 17 columns]

# %%
invoice.counter_type.value_counts()
# Out:
# ELEC    3079406
# GAZ     1397343
# Name: counter_type, dtype: int64

# %%
invoice.months_number.value_counts()
# Out:
# 4         3680478
# 8          278772
# 2          270909
# 1          113266
# 12          54328
#            ...
# 185658          1
# 226613          1
# 226612          1
# 107879          1
# 335711          1
# Name: months_number, Length: 1370, dtype: int64

# %% [markdown]
# Month number makes no sense. Remove it.

# %%
invoice.drop('months_number',axis=1,inplace=True)
invoice
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 0                    0           203                 8                    1
# 1                    0           203                 6                    1
# 2                    0           203                 8                    1
# 3                    0           207                 8                    1
# 4                    0           207                 9                    1
# ...                ...           ...               ...                  ...
# 4476744              0           202                 9                    1
# 4476745              0           202                 6                    1
# 4476746              0           203                 6                    1
# 4476747              0           203                 6                    1
# 4476748              0           203                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index counter_type  diff_index
# 0                           0      14302      14384         ELEC          82
# 1                           0      12294      13678         ELEC        1384
# 2                           0      14624      14747         ELEC         123
# 3                           0      14747      14849         ELEC         102
# 4                           0      15066      15638         ELEC         572
# ...                       ...        ...        ...          ...         ...
# 4476744                     0       3197       3732         ELEC         535
# 4476745                     0       3732       3938         ELEC         206
# 4476746                     0      13884      14143         ELEC         259
# 4476747                     0      13281      13884         ELEC         603
# 4476748                     0      12765      13281         ELEC         516
#
# [4476749 rows x 16 columns]

# %%
invoice.counter_coefficient.value_counts()
# Out:
# 1     4475102
# 2         886
# 3         321
# 40        197
# 30        137
# 0          46
# 6          30
# 4          12
# 10          6
# 9           3
# 20          3
# 50          2
# 5           1
# 8           1
# 11          1
# 33          1
# Name: counter_coefficient, dtype: int64

# %% [markdown]
# Checking if counter_coef ==1 and !=1 may be useful. We convert all values !=1 to be 0

# %%
invoice.counter_coefficient=invoice.counter_coefficient.apply(lambda x: 1 if x==1 else 0)
invoice
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 0                    0           203                 8                    1
# 1                    0           203                 6                    1
# 2                    0           203                 8                    1
# 3                    0           207                 8                    1
# 4                    0           207                 9                    1
# ...                ...           ...               ...                  ...
# 4476744              0           202                 9                    1
# 4476745              0           202                 6                    1
# 4476746              0           203                 6                    1
# 4476747              0           203                 6                    1
# 4476748              0           203                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index counter_type  diff_index
# 0                           0      14302      14384         ELEC          82
# 1                           0      12294      13678         ELEC        1384
# 2                           0      14624      14747         ELEC         123
# 3                           0      14747      14849         ELEC         102
# 4                           0      15066      15638         ELEC         572
# ...                       ...        ...        ...          ...         ...
# 4476744                     0       3197       3732         ELEC         535
# 4476745                     0       3732       3938         ELEC         206
# 4476746                     0      13884      14143         ELEC         259
# 4476747                     0      13281      13884         ELEC         603
# 4476748                     0      12765      13281         ELEC         516
#
# [4476749 rows x 16 columns]

# %% [markdown]
# We have no idea what counter_code is, so drop it!

# %%
invoice.drop('counter_code',axis=1,inplace=True)
invoice
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#         counter_statue  reading_remarque  counter_coefficient  \
# 0                    0                 8                    1
# 1                    0                 6                    1
# 2                    0                 8                    1
# 3                    0                 8                    1
# 4                    0                 9                    1
# ...                ...               ...                  ...
# 4476744              0                 9                    1
# 4476745              0                 6                    1
# 4476746              0                 6                    1
# 4476747              0                 6                    1
# 4476748              0                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index counter_type  diff_index
# 0                           0      14302      14384         ELEC          82
# 1                           0      12294      13678         ELEC        1384
# 2                           0      14624      14747         ELEC         123
# 3                           0      14747      14849         ELEC         102
# 4                           0      15066      15638         ELEC         572
# ...                       ...        ...        ...          ...         ...
# 4476744                     0       3197       3732         ELEC         535
# 4476745                     0       3732       3938         ELEC         206
# 4476746                     0      13884      14143         ELEC         259
# 4476747                     0      13281      13884         ELEC         603
# 4476748                     0      12765      13281         ELEC         516
#
# [4476749 rows x 15 columns]

# %%
invoice.counter_statue.value_counts()
# Out:
# 0         4346960
# 1           73496
# 0           32048
# 5           20495
# 4            2706
# 1             540
# 3             258
# 5             144
# 2              32
# 4              23
# 46             14
# A              13
# 618            12
# 769             6
# 420             1
# 269375          1
# Name: counter_statue, dtype: int64

# %% [markdown]
# Since we notice there is an A, in a numeric column, we convert it to a 0 to allow us to make the column numeric

# %%
invoice.counter_statue=invoice.counter_statue.apply(lambda x:x if x!='A' else 0)
invoice.counter_statue=invoice.counter_statue.astype('int32')
invoice
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#          counter_statue  reading_remarque  counter_coefficient  \
# 0                     0                 8                    1
# 1                     0                 6                    1
# 2                     0                 8                    1
# 3                     0                 8                    1
# 4                     0                 9                    1
# ...                 ...               ...                  ...
# 4476744               0                 9                    1
# 4476745               0                 6                    1
# 4476746               0                 6                    1
# 4476747               0                 6                    1
# 4476748               0                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index counter_type  diff_index
# 0                           0      14302      14384         ELEC          82
# 1                           0      12294      13678         ELEC        1384
# 2                           0      14624      14747         ELEC         123
# 3                           0      14747      14849         ELEC         102
# 4                           0      15066      15638         ELEC         572
# ...                       ...        ...        ...          ...         ...
# 4476744                     0       3197       3732         ELEC         535
# 4476745                     0       3732       3938         ELEC         206
# 4476746                     0      13884      14143         ELEC         259
# 4476747                     0      13281      13884         ELEC         603
# 4476748                     0      12765      13281         ELEC         516
#
# [4476749 rows x 15 columns]

# %%
invoice.counter_statue.value_counts()
# Out:
# 0         4379008
# 1           74036
# 5           20639
# 4            2729
# 3             258
# 2              32
# 46             14
# 100            13
# 618            12
# 769             6
# 420             1
# 269375          1
# Name: counter_statue, dtype: int64

# %%
invoice.counter_number.value_counts()
# Out:
# 0                43161
# 2786               251
# 630317             230
# 162709             226
# 963                220
#                  ...
# 2178800021043        1
# 21147                1
# 693955               1
# 359841               1
# 1323316              1
# Name: counter_number, Length: 201893, dtype: int64

# %%
invoice
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11         1335667
# 1            train_Client_0   2013-03-29          11         1335667
# 2            train_Client_0   2015-03-23          11         1335667
# 3            train_Client_0   2015-07-13          11         1335667
# 4            train_Client_0   2016-11-17          11         1335667
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10         1253571
# 4476745  train_Client_99998   2005-12-19          10         1253571
# 4476746  train_Client_99999   1996-09-25          11          560948
# 4476747  train_Client_99999   1996-05-28          11          560948
# 4476748  train_Client_99999   1996-01-25          11          560948
#
#          counter_statue  reading_remarque  counter_coefficient  \
# 0                     0                 8                    1
# 1                     0                 6                    1
# 2                     0                 8                    1
# 3                     0                 8                    1
# 4                     0                 9                    1
# ...                 ...               ...                  ...
# 4476744               0                 9                    1
# 4476745               0                 6                    1
# 4476746               0                 6                    1
# 4476747               0                 6                    1
# 4476748               0                 6                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                          82                     0                     0
# 1                        1200                   184                     0
# 2                         123                     0                     0
# 3                         102                     0                     0
# 4                         572                     0                     0
# ...                       ...                   ...                   ...
# 4476744                   400                   135                     0
# 4476745                   200                     6                     0
# 4476746                   259                     0                     0
# 4476747                   603                     0                     0
# 4476748                   516                     0                     0
#
#          consommation_level_4  old_index  new_index counter_type  diff_index
# 0                           0      14302      14384         ELEC          82
# 1                           0      12294      13678         ELEC        1384
# 2                           0      14624      14747         ELEC         123
# 3                           0      14747      14849         ELEC         102
# 4                           0      15066      15638         ELEC         572
# ...                       ...        ...        ...          ...         ...
# 4476744                     0       3197       3732         ELEC         535
# 4476745                     0       3732       3938         ELEC         206
# 4476746                     0      13884      14143         ELEC         259
# 4476747                     0      13281      13884         ELEC         603
# 4476748                     0      12765      13281         ELEC         516
#
# [4476749 rows x 15 columns]

# %%
invoice.groupby(by='client_id').tarif_type.mean()
# Out:
# client_id
# train_Client_0        11.000000
# train_Client_1        11.000000
# train_Client_10       11.000000
# train_Client_100      11.000000
# train_Client_1000     11.000000
#                         ...
# train_Client_99995    24.887324
# train_Client_99996    25.853659
# train_Client_99997    22.277778
# train_Client_99998    10.000000
# train_Client_99999    11.000000
# Name: tarif_type, Length: 135493, dtype: float64

# %% [markdown]
# # Plan:
# Try to summarize the invoice details about each client. Hence, we have a single row detailing the invoices by a single client. We can then merge the tables (Client and Invoice)
#
# # Summary statistics on different columns
#
# client_id:                  Keep it for merging
# invoice_date:               Drop it, since we cant summarize dates easily
# tarif_type:                 Mode
# counter_number:             Drop it
# counter_statue:             Drop it
# reading_remarque:           Min and Mode
# counter_coefficient:        Mode (1 and 0 only)
# consommation_level_1:       Mean and Std Div
# consommation_level_2:       Mean and Std Div
# consommation_level_3:       Mean and Std Div
# consommation_level_4:       Mean and Std Div
# old_index:                  Drop it
# new_index:                  Drop it
# counter_type:               Mode
# diff_index:                 Mean and Std Div

# %%
invoice=pd.read_csv("./train/invoice_train.csv")
# Out:
# C:\Users\rohan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
[x if isinstance(x,(int,np.int64)) else x[0] for x in invoice.groupby(by='client_id')['tarif_type'].agg(pd.Series.mode).to_list()]
# Out:
# [11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  12,
#  10,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  29,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  40,
#  40,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  40,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  40,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  10,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  13,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  12,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  45,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  10,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  11,
#  10,
#  10,
#  40,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  10,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  40,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  10,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  10,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  40,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  10,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  45,
#  11,
#  11,
#  40,
#  11,
#  11,
#  40,
#  11,
#  40,
#  11,
#  11,
#  11,
#  10,
#  40,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  40,
#  11,
#  10,
#  11,
#  11,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  11,
#  ...]

# %%
def summarizeInvoices(df):
    ''' df is the dataframe with the invoice data, in the same format as supplied'''
    ans=pd.DataFrame({'client_id':df.client_id.unique()})
    #colsToDrop=['invoice_date','counter_number','counter_statue']
    #df.drop(colsToDrop,axis=1,inplace=True)
    
    #Find the diff in index:
    ans['diff_index']=df['new_index']-df['old_index']
    df['diff_index']=df['new_index']-df['old_index']
    #df.drop(['new_index','old_index'],axis=1,inplace=True)
    
    # Make counter coefficent and type 0 and 1 only:
    df['counter_statue']=df.counter_statue.apply(lambda x:int(x) if x!='A' else 0)
    df['counter_type']=df.counter_type.apply(lambda x: 0 if x=='ELEC' else 1)
    
    print("Calculating the modes...")
    # All Mode values:
    colsToMode=['tarif_type','reading_remarque','counter_coefficient','counter_type']
    for col in colsToMode:
        ans[col+'_mode']=[x if isinstance(x,(int,np.int64)) else x[0] for x in 
                          df.groupby(by='client_id')[col].agg(pd.Series.mode).to_list()]
        
    print("Calculating the Means and Std div...")
    # All Mean and std values:
    colsToMean=['consommation_level_1','consommation_level_2','consommation_level_3','consommation_level_4','diff_index']
    for col in colsToMean:
        ans[col+'_mean']=df.groupby(by='client_id')[col].agg(pd.Series.mean).to_list()
        ans[col+'_stddiv']=df.groupby(by='client_id')[col].agg(pd.Series.std).to_list()
    
    print("Calculating the Min for reading_remarque...")
    # Min of reading_remarque:
    ans['reading_remarque_min']=[x if isinstance(x,(int,np.int64)) else x[0] for x in
                                df.groupby(by='client_id')['reading_remarque'].agg(pd.Series.min).to_list()]
    
    return ans

# %%
from time import time

# %%
print(invoice.columns)
t0=time()
newdf=summarizeInvoices(invoice)
print("Time taken:",time()-t0,'seconds')
print(newdf.columns)
# Out:
# Index(['client_id', 'invoice_date', 'tarif_type', 'counter_number',
#        'counter_statue', 'counter_code', 'reading_remarque',
#        'counter_coefficient', 'consommation_level_1', 'consommation_level_2',
#        'consommation_level_3', 'consommation_level_4', 'old_index',
#        'new_index', 'months_number', 'counter_type', 'diff_index'],
#       dtype='object')
# Calculating the modes...
# Calculating the Means and Std div...
# Calculating the Min for reading_remarque...
# Time taken: 187.32400012016296 seconds
# Index(['client_id', 'diff_index', 'tarif_type_mode', 'reading_remarque_mode',
#        'counter_coefficient_mode', 'counter_type_mode',
#        'consommation_level_1_mean', 'consommation_level_1_stddiv',
#        'consommation_level_2_mean', 'consommation_level_2_stddiv',
#        'consommation_level_3_mean', 'consommation_level_3_stddiv',
#        'consommation_level_4_mean', 'consommation_level_4_stddiv',
#        'diff_index_mean', 'diff_index_stddiv', 'reading_remarque_min'],
#       dtype='object')

# %%
newdf
# Out:
#                  client_id  diff_index  tarif_type_mode  \
# 0           train_Client_0          82               11
# 1           train_Client_1        1384               11
# 2          train_Client_10         123               11
# 3         train_Client_100         102               11
# 4        train_Client_1000         572               11
# ...                    ...         ...              ...
# 135488  train_Client_99995         819               11
# 135489  train_Client_99996         737               40
# 135490  train_Client_99997         274               11
# 135491  train_Client_99998         825               10
# 135492  train_Client_99999          91               11
#
#         reading_remarque_mode  counter_coefficient_mode  counter_type_mode  \
# 0                           6                         1                  0
# 1                           6                         1                  0
# 2                           6                         1                  0
# 3                           6                         1                  0
# 4                           9                         1                  0
# ...                       ...                       ...                ...
# 135488                      6                         1                  0
# 135489                      9                         1                  1
# 135490                      9                         1                  0
# 135491                      6                         1                  0
# 135492                      6                         1                  0
#
#         consommation_level_1_mean  consommation_level_1_stddiv  \
# 0                      352.400000                   310.343472
# 1                      557.540541                   197.935960
# 2                      798.611111                   513.841374
# 3                        1.200000                     3.607011
# 4                      663.714286                   224.831365
# ...                           ...                          ...
# 135488                   1.957746                    16.496265
# 135489                 185.853659                   200.935258
# 135490                 273.083333                   211.123441
# 135491                 300.000000                   141.421356
# 135492                 459.333333                   178.864008
#
#         consommation_level_2_mean  consommation_level_2_stddiv  \
# 0                       10.571429                    43.568935
# 1                        0.000000                     0.000000
# 2                       37.888889                   160.748942
# 3                        0.000000                     0.000000
# 4                      104.857143                   167.155320
# ...                           ...                          ...
# 135488                   0.000000                     0.000000
# 135489                   0.756098                     4.841387
# 135490                   0.000000                     0.000000
# 135491                  70.500000                    91.216775
# 135492                   0.000000                     0.000000
#
#         consommation_level_3_mean  consommation_level_3_stddiv  \
# 0                        0.000000                     0.000000
# 1                        0.000000                     0.000000
# 2                        0.000000                     0.000000
# 3                        0.000000                     0.000000
# 4                      117.357143                   289.433294
# ...                           ...                          ...
# 135488                   0.000000                     0.000000
# 135489                   0.000000                     0.000000
# 135490                   0.000000                     0.000000
# 135491                   0.000000                     0.000000
# 135492                   0.000000                     0.000000
#
#         consommation_level_4_mean  consommation_level_4_stddiv  \
# 0                        0.000000                     0.000000
# 1                        0.000000                     0.000000
# 2                        0.000000                     0.000000
# 3                        0.000000                     0.000000
# 4                       36.714286                   105.421081
# ...                           ...                          ...
# 135488                   0.000000                     0.000000
# 135489                   0.000000                     0.000000
# 135490                   0.000000                     0.000000
# 135491                   0.000000                     0.000000
# 135492                   0.000000                     0.000000
#
#         diff_index_mean  diff_index_stddiv  reading_remarque_min
# 0            362.971429         341.553930                     6
# 1            557.540541         197.935960                     6
# 2            836.500000         646.808386                     6
# 3              1.200000           3.607011                     6
# 4            922.642857         633.485669                     8
# ...                 ...                ...                   ...
# 135488         0.000000           0.000000                     6
# 135489       186.609756         203.347840                     6
# 135490       273.083333         211.123441                     9
# 135491       370.500000         232.638131                     6
# 135492       459.333333         178.864008                     6
#
# [135493 rows x 17 columns]

# %%
newdf.to_csv("Cleaned Invoices.csv",index=False)

# %%
client=pd.read_csv('./train/client_train.csv')

# %%
client
# Out:
#         disrict           client_id  client_catg  region creation_date  target
# 0            60      train_Client_0           11     101    31/12/1994     0.0
# 1            69      train_Client_1           11     107    29/05/2002     0.0
# 2            62     train_Client_10           11     301    13/03/1986     0.0
# 3            69    train_Client_100           11     105    11/07/1996     0.0
# 4            62   train_Client_1000           11     303    14/10/2014     0.0
# ...         ...                 ...          ...     ...           ...     ...
# 135488       62  train_Client_99995           11     304    26/07/2004     0.0
# 135489       63  train_Client_99996           11     311    25/10/2012     0.0
# 135490       63  train_Client_99997           11     311    22/11/2011     0.0
# 135491       60  train_Client_99998           11     101    22/12/1993     0.0
# 135492       60  train_Client_99999           11     101    18/02/1986     0.0
#
# [135493 rows x 6 columns]

# %%
client.disrict.value_counts()
# Out:
# 62    40353
# 69    34231
# 60    31922
# 63    28987
# Name: disrict, dtype: int64

# %%
client.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135493 entries, 0 to 135492
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   disrict        135493 non-null  int64
#  1   client_id      135493 non-null  object
#  2   client_catg    135493 non-null  int64
#  3   region         135493 non-null  int64
#  4   creation_date  135493 non-null  object
#  5   target         135493 non-null  float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 6.2+ MB

# %%
def combineDataset(client,invoice):
    '''Client is directly read from original file
    Invoice is preprocessed with summarizeInvoices() function'''
    
    #convert to datetime objects
    client['creation_date']=pd.to_datetime(client['creation_date'])
    
    #We expect the region codes to have geographical meaning, in terms of the values assigned (Eg: 100 to 199 may be of the same region)
    client['region']=client['region'].apply(lambda x: int(str(x)[0]))
    
    finaldf=client.merge(newdf,on='client_id',how='left')
    return finaldf

# %%
res=combineDataset(client,newdf)
res
# Out:
#         disrict           client_id  client_catg  region creation_date  \
# 0            60      train_Client_0           11       1    1994-12-31
# 1            69      train_Client_1           11       1    2002-05-29
# 2            62     train_Client_10           11       3    1986-03-13
# 3            69    train_Client_100           11       1    1996-11-07
# 4            62   train_Client_1000           11       3    2014-10-14
# ...         ...                 ...          ...     ...           ...
# 135488       62  train_Client_99995           11       3    2004-07-26
# 135489       63  train_Client_99996           11       3    2012-10-25
# 135490       63  train_Client_99997           11       3    2011-11-22
# 135491       60  train_Client_99998           11       1    1993-12-22
# 135492       60  train_Client_99999           11       1    1986-02-18
#
#         target  diff_index  tarif_type_mode  reading_remarque_mode  \
# 0          0.0          82               11                      6
# 1          0.0        1384               11                      6
# 2          0.0         123               11                      6
# 3          0.0         102               11                      6
# 4          0.0         572               11                      9
# ...        ...         ...              ...                    ...
# 135488     0.0         819               11                      6
# 135489     0.0         737               40                      9
# 135490     0.0         274               11                      9
# 135491     0.0         825               10                      6
# 135492     0.0          91               11                      6
#
#         counter_coefficient_mode  ...  consommation_level_1_stddiv  \
# 0                              1  ...                   310.343472
# 1                              1  ...                   197.935960
# 2                              1  ...                   513.841374
# 3                              1  ...                     3.607011
# 4                              1  ...                   224.831365
# ...                          ...  ...                          ...
# 135488                         1  ...                    16.496265
# 135489                         1  ...                   200.935258
# 135490                         1  ...                   211.123441
# 135491                         1  ...                   141.421356
# 135492                         1  ...                   178.864008
#
#         consommation_level_2_mean  consommation_level_2_stddiv  \
# 0                       10.571429                    43.568935
# 1                        0.000000                     0.000000
# 2                       37.888889                   160.748942
# 3                        0.000000                     0.000000
# 4                      104.857143                   167.155320
# ...                           ...                          ...
# 135488                   0.000000                     0.000000
# 135489                   0.756098                     4.841387
# 135490                   0.000000                     0.000000
# 135491                  70.500000                    91.216775
# 135492                   0.000000                     0.000000
#
#         consommation_level_3_mean  consommation_level_3_stddiv  \
# 0                        0.000000                     0.000000
# 1                        0.000000                     0.000000
# 2                        0.000000                     0.000000
# 3                        0.000000                     0.000000
# 4                      117.357143                   289.433294
# ...                           ...                          ...
# 135488                   0.000000                     0.000000
# 135489                   0.000000                     0.000000
# 135490                   0.000000                     0.000000
# 135491                   0.000000                     0.000000
# 135492                   0.000000                     0.000000
#
#         consommation_level_4_mean  consommation_level_4_stddiv  \
# 0                        0.000000                     0.000000
# 1                        0.000000                     0.000000
# 2                        0.000000                     0.000000
# 3                        0.000000                     0.000000
# 4                       36.714286                   105.421081
# ...                           ...                          ...
# 135488                   0.000000                     0.000000
# 135489                   0.000000                     0.000000
# 135490                   0.000000                     0.000000
# 135491                   0.000000                     0.000000
# 135492                   0.000000                     0.000000
#
#         diff_index_mean  diff_index_stddiv  reading_remarque_min
# 0            362.971429         341.553930                     6
# 1            557.540541         197.935960                     6
# 2            836.500000         646.808386                     6
# 3              1.200000           3.607011                     6
# 4            922.642857         633.485669                     8
# ...                 ...                ...                   ...
# 135488         0.000000           0.000000                     6
# 135489       186.609756         203.347840                     6
# 135490       273.083333         211.123441                     9
# 135491       370.500000         232.638131                     6
# 135492       459.333333         178.864008                     6
#
# [135493 rows x 22 columns]

# %%
res.to_csv("Final Train Data.csv",index=False)

# %%
res.counter_coefficient_mode.value_counts()
# Out:
# 1     135458
# 2         19
# 3          9
# 6          2
# 40         2
# 20         1
# 30         1
# 50         1
# Name: counter_coefficient_mode, dtype: int64

# %% [markdown]
# --------------------------------------

# %% [markdown]
# Load "Final Train Data.csv"
# Train test split: 80/20 train/test split (make sure to stratify with y)
# 1) Oversample      Rohan
# 2) Undersample     Abdel Rahman
# 3) SMOTE           Ilham
# 4) None (baseline) Farah
# SMOTEomek library does all of this^
#
# Each person does this:
# Run models: Logistic Regression (baseline), Naive Bayes, Decision Tree, Random Forest, KNN, SVM (linear, poly,rbf), LGBM
# Measure metrics: Accuracy, Recall, Precision, F1 Score, AUC ROC
